# %% [markdown]
# # Scraping insight AI fellows data

# %% [markdown]
# In this notebook, I'll extract data about insight fellows in order to learn more about past programs fellows and the kind of jobs they obtain after completing the program. I'll use `requests` for obtaining webpages, `Beautiful Soup` for parsing webpages and extracting data and `pandas` for analyzing the data.

# %% [markdown]
# ### import libraries:

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get web page:

# %%
url = 'https://www.insightdata.ai/fellows'
response = requests.get(url)

# %% [markdown]
# ### Extract content:

# %% [markdown]
# First, let's look at the entire html structure to understand how it is built and what would we want to extract

# %%
content = BeautifulSoup(response.content, 'html.parser')
print(content.prettify())
# Out:
# <!DOCTYPE html>
# <!-- Last Published: Sat Mar 09 2019 18:15:03 GMT+0000 (UTC) -->
# <html data-wf-domain="www.insightdata.ai" data-wf-page="5be37f7506d41c276f39a4ea" data-wf-site="57c954d37d70832a623199f5" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Insight Artificial Intelligence Fellows
#   </title>
#   <meta content="Insight Artificial Intelligence Fellows" property="og:title"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://uploads-ssl.webflow.com/57c954d37d70832a623199f5/css/insight-artificial-intelligence.507b351b5.min.css" rel="stylesheet" type="text/css"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/webfont/1.4.7/webfont.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    WebFont.load({  google: {    families: ["Open Sans:300,300italic,400,400italic,600,600italic,700,700italic,800,800italic"]  }});
#   </script>
#   <!--[if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js" type="text/javascript"></script><![endif]-->
#   <script type="text/javascript">
#    !function(o,c){var n=c.documentElement,t=" w-mod-";n.className+=t+"js",("ontouchstart"in o||o.DocumentTouch&&c instanceof DocumentTouch)&&(n.className+=t+"touch")}(window,document);
#   </script>
#   <link href="https://daks2k3a4ib2z.cloudfront.net/57c954d37d70832a623199f5/57c954d37d70832a62319aa2_favicon-32x32.png" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://daks2k3a4ib2z.cloudfront.net/57c954d37d70832a623199f5/57c954d37d70832a62319aa1_favicon-256x256.png" rel="apple-touch-icon"/>
#   <script type="text/javascript">
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';n.agent='plwebflow';n.queue=[];t=b.createElement(e);t.async=!0;t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,document,'script','https://connect.facebook.net/en_US/fbevents.js');fbq('init', '727689120904384');fbq('track', 'PageView');
#   </script>
#   <style>
#    .active_item_blue { border-bottom: 3px solid #577ada !important; padding-bottom: 6px !important; }
#   .active_item_green { border-bottom: 3px solid #49a99b !important; padding-bottom: 6px !important; }
#   .active_item_orange { border-bottom: 3px solid #513f7a !important; padding-bottom: 6px !important; }
#   .circle_container { z-index: 50 !important; }
#   </style>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-29720873-1', 'auto', {allowLinker: true});
#   ga('require', 'linker');
#   ga('send', 'pageview');
#   ga('linker:autoLink', ['blog.insightdatascience.com', 'insightdatascience.com', 'insightdataengineering.com', 'insighthealthdata.com', 'insightdata.ai', 'insightdevops.com']);
#   </script>
#   <style>
#    @media screen and (max-width: 480px) {
#     .fellows_grid {
#     	margin-left:5%;
#     }
# }
# .fellow_item:hover .fellows_tooltip { display: block; }
# .all_headers_container{ overflow: hidden; white-space: nowrap; vertical-align: top; }
# .nav_item_middle:hover .middle_nav_item { opacity: 1; }
# .slide_container_1 { position: absolute !important; }
# .slide_container_2 { position: absolute !important; }
# .slide_container_3 { position: absolute !important; }
# .slide_container_4 { position: absolute !important; }
# .program_slide_1, .program_slide_2, .program_slide_3, .program_slide_4 { position: absolute !important;}
# .fellows_slide_1, .fellows_slide_2, .fellows_slide_3, .fellows_slide_4, .fellows_slide_5 { position: absolute !important;}
# .mentorship_slide_1, .mentorship_slide_2 { position: absolute !important;}
# .industry_slide_1, .industry_slide_2 { position: absolute !important;}
# .community_slide_1, .community_slide_2 { position: absolute !important;}
# #link_program:hover { color: #4f3e78; border-top: 3px solid #efefef; border-left: 3px solid #efefef; border-right: 3px solid #efefef; background: #fafafa; }
# .header_slider { overflow: hidden !important; }
# .apply_now_btn { vertical-align: top;}
# .btn_signup { vertical-align: top;}
# .mobile_nav_button { cursor: pointer; }
# .mobile_active_nav { color: #587adb !important; }
# .program_slide_item { box-sizing: border-box; vertical-align: top;}
# .fellows_slide_item { box-sizing: border-box; vertical-align: top;}
# .mentorship_slide_item { box-sizing: border-box; vertical-align: top;}
# .industry_slide_item { box-sizing: border-box; vertical-align: top;}
# .community_slide_item { box-sizing: border-box; vertical-align: top;}
# .industry_slide1_content { white-space: normal;}
# .it_transparent_text { white-space: normal;}
# .caption_text { white-space: normal;}
# .nav_item_faq:hover .nav_text_item {opacity:1;}
# .faq_category_item {cursor: pointer;}
# .question { vertical-align: middle;}
#
# .blue_link:active, .blue_link:link, .blue_link:visited, .blue_link:hover {color: #577ada;}
#
# .circle { width: 16px; height: 16px; border-radius: 50%; border: 2px solid rgba(255,255,255, 0.5); margin: 0px 8px; display: inline-block; cursor: pointer; -webkit-transition: all 0.2s; -moz-transition: all 0.2s; -ms-transition: all 0.2s; -o-transition: all 0.2s; transition: all 0.2s; }
# .circle:hover { background-color: #FFF; border: 2px solid #FFF; }
# .filled { background-color: #FFF; border: 2px solid #FFF; }
#
# .blue_circle { width: 12px; height: 12px; border-radius:50%; border: 3px solid #aabbea; margin: 0px 8px; display: inline-block; cursor: pointer; -webkit-transition: all 0.2s; -moz-transition: all 0.2s; -ms-transition: all 0.2s; -o-transition: all 0.2s; transition: all 0.2s;}
# .blue_circle:hover { background-color: #4f3e78; border: 3px solid #4f3e78;}
# .blue_filled { background-color: #4f3e78; border: 3px solid #4f3e78;}
#
# /* animations */
# .slide_inactive { left: 150% !important; }
# @keyframes slide_from_left_anim {
#     from { left: 150%; }
#     to { left: 50%; }
# }
# .slide_from_left {
# 	animation-fill-mode: forwards;
#     animation-name: slide_from_left_anim;
#     animation-duration: 1s;
# }
#
# @keyframes slide_to_right_anim {
#     from { left: 50%; }
#     to { left: -150%; }
# }
# .slide_to_right {
# 	animation-fill-mode: forwards;
#     animation-name: slide_to_right_anim;
#     animation-duration: 1s;
# }
# /* animations */
#
# /* animations header*/
# .slide_inactive_h { left: 100% !important; }
# @keyframes slide_from_left_anim_h {
#     from { left: 100%; }
#     to { left: 0%; }
# }
# .slide_from_left_h {
# 	animation-fill-mode: forwards;
#     animation-name: slide_from_left_anim_h;
#     animation-duration: 1s;
# }
#
# @keyframes slide_to_right_anim_h {
#     from { left: 0%; }
#     to { left: -100%; }
# }
# .slide_to_right_h {
# 	animation-fill-mode: forwards;
#     animation-name: slide_to_right_anim_h;
#     animation-duration: 1s;
# }
# /* animations header*/
#   </style>
#  </head>
#  <body>
#   <div class="full_website w-clearfix" id="full_website">
#    <div class="logo_nav">
#     <div class="upper_header_wrapper w-clearfix">
#      <a class="site_logo w-inline-block" href="/">
#       <img alt="" src="https://uploads-ssl.webflow.com/57c954d37d70832a623199f5/57c954d37d70832a62319a5b_insight_logo.png"/>
#      </a>
#      <div class="middle_nav">
#       <a class="health_nav_it w-inline-block" href="http://insightdatascience.com" id="header_bt_1">
#        <div class="health_nav_text">
#         data science
#        </div>
#       </a>
#       <a class="health_nav_it middle w-inline-block" href="http://insightdataengineering.com" id="header_bt_2">
#        <div class="health_nav_text">
#         data engineering
#        </div>
#       </a>
#       <a class="health_nav_it middle w-inline-block" href="http://insighthealthdata.com/" id="header_bt_2">
#        <div class="health_nav_text">
#         health data
#        </div>
#       </a>
#       <a class="health_nav_it middle w-inline-block" href="/" id="header_bt_3">
#        <div class="health_nav_text">
#         AI
#        </div>
#       </a>
#       <a class="health_nav_it middle w-inline-block" href="http://insightdatapm.com/" id="header_bt_3">
#        <div class="health_nav_text">
#         Data PM
#        </div>
#       </a>
#       <a class="health_nav_it middle w-inline-block" href="https://www.insightdevops.com/" id="header_bt_3">
#        <div class="health_nav_text">
#         DEVOPS
#        </div>
#       </a>
#       <a class="health_nav_it middle w-inline-block" href="https://www.insightconsensus.com/" id="header_bt_3">
#        <div class="health_nav_text">
#         Consensus
#        </div>
#       </a>
#      </div>
#      <div class="right_nav blue_link">
#       <a class="right_nav_item orange_nav w-inline-block w--current" href="/fellows" id="header_bt_6">
#        <div class="right_nav_item_text padding">
#         Fellows
#        </div>
#       </a>
#       <a class="right_nav_item orange_nav w-inline-block" href="https://www.insightdatascience.com/apply" id="header_bt_6">
#        <div class="right_nav_item_text padding">
#         APPLY
#        </div>
#       </a>
#       <a class="right_nav_item orange_nav hide w-inline-block" href="/faq" id="header_bt_7">
#        <div class="right_nav_item_text padding">
#         faq
#        </div>
#       </a>
#       <a class="right_nav_item orange_nav w-inline-block" href="/faq" id="header_bt_6">
#        <div class="right_nav_item_text padding">
#         FAQ
#        </div>
#       </a>
#       <a class="right_nav_item orange_nav w-inline-block" href="https://blog.insightdatascience.com/tagged/insight-ai" id="header_bt_8" target="_blank">
#        <div class="right_nav_item_text padding">
#         blog
#        </div>
#       </a>
#      </div>
#      <img alt="" class="mobile_nav_button orange_button" src="https://uploads-ssl.webflow.com/57c954d37d70832a623199f5/57c95a580f1d7eeb6128b20e_mobile_nav_button_violet.png"/>
#     </div>
#    </div>
#    <div class="fellows_content" id="header">
#     <div class="fellows_title">
#      AI Fellows
#     </div>
#     <div class="fellows_subtitle">
#      Over 50 Insight Artificial Intelligence alumni are now ML researchers and engineers
#     </div>
#     <div class="fellows_grid">
#      <div class="fellows_list w-dyn-list">
#       <div class="w-clearfix w-dyn-items w-row">
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Anitha Priya Krishnan
#            </div>
#            <div class="toottip_title">
#             Bioinformatics scientist
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Chan Zuckerberg Biohub
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Reducing the memory requirements of trained neural networks using weight pruning
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Biomedical Engineering, Rochester University, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5af20495a3c1db01450edfd6_20170306-_DSC6083.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Anitha Priya Krishnan
#           </div>
#           <div class="fellow_company">
#            Chan Zuckerberg Biohub
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Bob Guo
#            </div>
#            <div class="toottip_title">
#             Senior ML Scientist
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Amazon Alexa
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Colorizing gray images using HyperColumns and convolutional neural networks (CNNs)
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Electrical Engineering, Peking University, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5af20478d68c44116c35f829_20170306-_DSC6073.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Bob Guo
#           </div>
#           <div class="fellow_company">
#            Amazon Alexa
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             David Gainer
#            </div>
#            <div class="toottip_title">
#             Software Engineer
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Google
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Bringing Synthetic Faces to Life using deep learning
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Computer Science, Columbia University, MS
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5af2045859312f1bd63e08cb_20170306-_DSC6079.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            David Gainer
#           </div>
#           <div class="fellow_company">
#            Google
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Drumil Deshpande
#            </div>
#            <div class="toottip_title">
#             Software Engineer - ML
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Applicantz
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            An end to end system to generate tags and captions describing videos
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Computer Science, University of Florida, MS
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5af20433030137e06b9a8a6d_20170306-_DSC6036.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Drumil Deshpande
#           </div>
#           <div class="fellow_company">
#            Applicantz
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Emmanuel Ameisen
#            </div>
#            <div class="toottip_title">
#             AI Lead
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Insight
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Applying Neural Style Transfer to Speech
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Data Scientist, Zipcar
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5af225be5560cfa4c15f94b3_20170306-_DSC6034.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Emmanuel Ameisen
#           </div>
#           <div class="fellow_company">
#            Insight
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Edward Kim
#            </div>
#            <div class="toottip_title">
#             ML Engineer
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Agero
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Real-time video super-resolution
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Astronomy, University of Illinois Urbana-Champaign, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5af226125560cfd34c5f94d2_20170306-_DSC6097.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Edward Kim
#           </div>
#           <div class="fellow_company">
#            Agero
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Jeffrey Hetherly
#            </div>
#            <div class="toottip_title">
#             Deep Learning Software Engineer
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             NVIDIA
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Audio upsampling using deep learning
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Physics, Southern Methodist University, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5af22a49c62be56bde9e6d89_Jeffrey.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Jeffrey Hetherly
#           </div>
#           <div class="fellow_company">
#            NVIDIA
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Lily Hu
#            </div>
#            <div class="toottip_title">
#             Research Scientist
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Salesforce Research
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            CNNs for image segmentation to separate overlapping chromosomes
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Mechanical Engineering, UC Berkeley, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5af37dce1f61901201e0e763_Lily.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Lily Hu
#           </div>
#           <div class="fellow_company">
#            Salesforce Research
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Markus Huber
#            </div>
#            <div class="toottip_title">
#             Senior Data Scientist
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Climate Corporation
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Generation of artificial images of face aging using constrained GANs
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Astrophysics, Ludwig-Maximillians University, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b328080ecd43fba60ff5bd4_Markus.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Markus Huber
#           </div>
#           <div class="fellow_company">
#            Climate Corporation
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Natalie Serrino
#            </div>
#            <div class="toottip_title">
#             Founding Engineer
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Stealth Startup
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Generating complementary harmonies for melody sequences using LSTM and HMM models
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Senior Software Engineer, Trifacta
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b3281a3e7336f413031f5e8_Natalie.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Natalie Serrino
#           </div>
#           <div class="fellow_company">
#            Stealth Startup
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Ramesh Sampath
#            </div>
#            <div class="toottip_title">
#             Deep Learning Engineer
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Lily AI
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Fashion apparel attributes API using deep learning
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Engineering Fellow, Code for America
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b3281fe1a8bf56b20f00e6c_Ramesh.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Ramesh Sampath
#           </div>
#           <div class="fellow_company">
#            Lily AI
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Richard Fisher
#            </div>
#            <div class="toottip_title">
#             NLP / Deep Learning Engineer
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Mya Systems
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Implementing Fast Weights, a new memory architecture geared for production, in a major NLP task
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Software Engineer, Myolo
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b32823a69229150233e38a2_Richard.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Richard Fisher
#           </div>
#           <div class="fellow_company">
#            Mya Systems
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Yao Zhao
#            </div>
#            <div class="toottip_title">
#             Applied Scientist II
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Microsoft AI &amp; Research
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Generating realistic images from captions, using Generative Adversarial Networks and text embeddings
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Applied Physics, Yale University, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b3282801a8bf542c9f00eb2_Yao.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Yao Zhao
#           </div>
#           <div class="fellow_company">
#            Microsoft AI &amp; Research
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Zhonglin Han
#            </div>
#            <div class="toottip_title">
#             Senior Engineer of Machine Learning
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Smule
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Audio Classification for Cobalt Robotics using deep transfer learning
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Nuclear Physics, Duke University, MS
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b3282c71a8bf5af17f00ed1_Zhonglin.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Zhonglin Han
#           </div>
#           <div class="fellow_company">
#            Smule
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Zhongyu Kuang
#            </div>
#            <div class="toottip_title">
#             Software Engineer
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Google
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Automatically adding/removing smiles from faces using deep adversarial models
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Atmospheric Science, Rutgers University, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b328315efc4567854fcc549_Zhongyu.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Zhongyu Kuang
#           </div>
#           <div class="fellow_company">
#            Google
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Andrew Mauboussin
#            </div>
#            <div class="toottip_title">
#             Data Scientist
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Twitter
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Explaining the predictions of any (text) classifier
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Data Scientist and Engineer, Kensho Technologies,
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b48585cb9f372054c210464_Andrew%20M%20Web-071817-001.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Andrew Mauboussin
#           </div>
#           <div class="fellow_company">
#            Twitter
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Bruno Guisard
#            </div>
#            <div class="toottip_title">
#             Machine Learning Engineer
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Liftoff Mobile, Inc
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Davis: Deep Learning Analytics in Video Stream
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Director of International Delta One and Arbitrage Trading, Deutsche Bank
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b48588cc575599bccd790f0_Bruno%20G%20Web-071817-001.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Bruno Guisard
#           </div>
#           <div class="fellow_company">
#            Liftoff Mobile, Inc
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Chuck-Hou Yee
#            </div>
#            <div class="toottip_title">
#             Machine Learning Research Engineer
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Imagen Technologies
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Cardiac MRI segmentation: Using deep nets to identify right ventricles
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Physics, Rutgers University, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b485958b9f3720b0c210548_Chuck-Hou%20Y%20Web-071817-002.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Chuck-Hou Yee
#           </div>
#           <div class="fellow_company">
#            Imagen Technologies
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Florent Bekerman
#            </div>
#            <div class="toottip_title">
#             Software Engineering - Machine Learning
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             LinkedIn
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Detecting links on network graphs
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Mathematics, MIT, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b485a3b95056d0954725136_Florent%20B%20Web-071817-002.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Florent Bekerman
#           </div>
#           <div class="fellow_company">
#            LinkedIn
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Gianni Galbiati
#            </div>
#            <div class="toottip_title">
#             Research Engineer
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Vidrovr
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Unsupervised learning for video representations
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Computational Psychology and Neuroscience, NYU, MS
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b485ab2b9f372acae2107df_Gianni%20G%20Web-071817-001.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Gianni Galbiati
#           </div>
#           <div class="fellow_company">
#            Vidrovr
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Godfred Somua-Gyimah
#            </div>
#            <div class="toottip_title">
#             Data Scientist
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Monsanto Company
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            SmartSurv: A 3D CNN that recognizes actions in video surveillance
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Mining Engineering, Missouri University of Science and Technology, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b485b1eb9f372b85a210b55_Godfred%20G%20Web-071817-002.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Godfred Somua-Gyimah
#           </div>
#           <div class="fellow_company">
#            Monsanto Company
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Jashmi Lagisetty
#            </div>
#            <div class="toottip_title">
#             Data Scientist
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             SparkCognition
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Image encoding and reconstruction using convolutional variational autoencoders
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Computer Science, Arizona State University, MS
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b485ba233b04eec5046a4f7_Jashmi%20Web-071817-002.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Jashmi Lagisetty
#           </div>
#           <div class="fellow_company">
#            SparkCognition
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             John Riskas
#            </div>
#            <div class="toottip_title">
#             Applied Deep Learning Researcher
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             DigitalGlobe
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            CureSkin: A deep learning dermatologist
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Emerging Markets Synthetic Equities Delta One Trader, Deutsche Bank
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b485bf19918ea2680ad7bb7_John%20R%20Web-071817-001.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            John Riskas
#           </div>
#           <div class="fellow_company">
#            DigitalGlobe
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Jonathan Kyl
#            </div>
#            <div class="toottip_title">
#             Artificial Intelligence Lead
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             JobMap.ai
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Show &amp; Tell at first sight: 1-shot image captioning
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Computer Science, University of Chicago, MS
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b485c95b9d114a75cb1af8e_Jonathan%20K%20Web-071817-001.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Jonathan Kyl
#           </div>
#           <div class="fellow_company">
#            JobMap.ai
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Prashanth Harshangi
#            </div>
#            <div class="toottip_title">
#             Senior AI Scientist
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             NIO
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            What do you see? Using deep learning for image-based Q&amp;A
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Adaptive Systems, Yale University, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b485cf3b9d114e7cbb1afa7_Prashamth%20H%20Web-071817-002.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Prashanth Harshangi
#           </div>
#           <div class="fellow_company">
#            NIO
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
# ...
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Shoaib Khan
#            </div>
#            <div class="toottip_title">
#             Data Scientist
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Manifold Technology
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Speak Again: Giving Voice to the Speech Impaired
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Computer Science and Engineering &amp; Applied Physics, University of North Texas, MS
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b486bb8b9f3725cf2212039_Shoaib%20Khan.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Shoaib Khan
#           </div>
#           <div class="fellow_company">
#            Manifold Technology
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Sumeet Agrawal
#            </div>
#            <div class="toottip_title">
#             ML Engineer
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Microsoft AI &amp; Research
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Thumbnails for Videos: A thumbnail worth a thousand frames
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Data Science, University of Southern California, MS
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b486c1760c9f4fbcc7b6c7b_Sumeet%20Agrawal.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Sumeet Agrawal
#           </div>
#           <div class="fellow_company">
#            Microsoft AI &amp; Research
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Tianxiao Jiang
#            </div>
#            <div class="toottip_title">
#             Technical Staff Member
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Cerebras Systems
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            SimpleText: Neural Text Simplification
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Computational Neuroscience, University of Houston, PhD
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b486c80b9f372cb5221210a_Tianxiao%20Jiang.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Tianxiao Jiang
#           </div>
#           <div class="fellow_company">
#            Cerebras Systems
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="fellow_item w-dyn-item w-col w-col-2">
#         <div class="fellows_tooltip">
#          <div class="arrow_down">
#          </div>
#          <div class="tooltip_header orange_header">
#           <div class="tooltip_header_container">
#            <div class="tooltip_name">
#             Victor Suthichai
#            </div>
#            <div class="toottip_title">
#             SDE, Deep Learning Platform
#            </div>
#            <div class="comma">
#             ,
#            </div>
#            <div class="tooltip_company">
#             Amazon AWS
#            </div>
#           </div>
#          </div>
#          <div class="tooltip_content">
#           <div class="tooltip_title">
#            Insight Project
#           </div>
#           <div class="tooltip_project">
#            Pair-a-phrase it: Siri: Sorry, I didn’t get that.
#           </div>
#           <div class="tooltip_title">
#            background
#           </div>
#           <div class="tooltip_background">
#            Senior ML Engineer, eHarmony
#           </div>
#          </div>
#         </div>
#         <div class="fellow_img orange_img" style='background-image:url("https://uploads-ssl.webflow.com/57c954d37d70832a623199f9/5b486cdab9f372330b212120_Victor%20Suthichai.jpg")'>
#          <div class="fellow_caption_back">
#           <div class="fellow_name">
#            Victor Suthichai
#           </div>
#           <div class="fellow_company">
#            Amazon AWS
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="section6 orange_bg">
#     <div class="section6_container">
#      <a class="apply_now_btn apply_orange w-inline-block" href="/apply">
#       <div class="apply_now_btn_text">
#        apply now
#       </div>
#      </a>
#      <a class="btn_signup w-inline-block" href="/health-data-notifications-list">
#       <div class="btn_signup_text">
#        Sign up for notification
#       </div>
#      </a>
#     </div>
#    </div>
#    <div class="footer">
#     <div class="footer_container">
#      <div class="footer_left">
#       <a class="health_nav_it w-inline-block" href="/">
#        <div class="health_nav_text">
#         data science
#        </div>
#       </a>
#       <a class="health_nav_it middle w-inline-block" href="/data-engineering">
#        <div class="health_nav_text">
#         data engineering
#        </div>
#       </a>
#       <a class="health_nav_it middle active w-inline-block" href="/">
#        <div class="health_nav_text active">
#         health data
#        </div>
#       </a>
#       <div class="invisible_sep margin-bottom">
#       </div>
#       <a class="right_nav_item orange_nav active_orange w-inline-block w--current" href="/fellows">
#        <div class="right_nav_item_text">
#         fellows
#        </div>
#       </a>
#       <a class="right_nav_item bottom orange_nav w-inline-block" href="/apply">
#        <div class="right_nav_item_text padding bottom">
#         apply
#        </div>
#       </a>
#       <a class="right_nav_item bottom orange_nav w-inline-block" href="http://insight-data-labs-sd.webflow.io/blog">
#        <div class="right_nav_item_text padding bottom">
#         blog
#        </div>
#       </a>
#       <a class="right_nav_item bottom orange_nav hide w-inline-block" href="/faq">
#        <div class="right_nav_item_text padding bottom">
#         faq
#        </div>
#       </a>
#       <div class="invisible_sep margin-bottom">
#       </div>
#      </div>
#      <div class="footer_right">
#       <a class="w-inline-block" href="https://twitter.com/insightdatalabs">
#        <div class="twitter_icon1 orange">
#        </div>
#       </a>
#       <a class="w-inline-block" href="https://www.facebook.com/InsightDataScience/">
#        <div class="facebook_icon1 orange">
#        </div>
#       </a>
#       <a class="w-inline-block" href="https://www.linkedin.com/company/insight-data-science">
#        <div class="linkedin_icon1 orange">
#        </div>
#       </a>
#       <a class="w-inline-block" href="mailto:datalabs@insightdatascience.com">
#        <div class="mail_icon1 orange">
#        </div>
#       </a>
#       <a class="footer_mail_link" href="mailto:info@insightdatascience.com">
#        info@insightdatascience.com
#       </a>
#       <div class="copy_text">
#        ©2016 Insight Data Science. Fellows
#        <em>
#         first
#        </em>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="side_nav_bar" id="side_nav_bar">
#    <div class="mobile_button_wrapper">
#     <a class="mobile_nav_item mobile_orange w-inline-block" href="http://insightdatascience.com">
#      <div>
#       data science
#      </div>
#     </a>
#     <a class="mobile_nav_item mobile_orange w-inline-block" href="http://insightdataengineering.com/">
#      <div>
#       data engineering
#      </div>
#     </a>
#     <a class="mobile_nav_item mobile_orange w-inline-block" href="http://insighthealthdata.com">
#      <div>
#       health data
#      </div>
#     </a>
#     <a class="mobile_nav_item mobile_orange w-inline-block" href="/">
#      <div>
#       Artificial intelligence
#      </div>
#     </a>
#     <a class="mobile_nav_item mobile_orange w-inline-block" href="https://www.insightdatapm.com/">
#      <div>
#       Data PM
#      </div>
#     </a>
#     <a class="mobile_nav_item mobile_orange w-inline-block" href="https://www.insightdevops.com/">
#      <div>
#       DevOps
#      </div>
#     </a>
#     <a class="mobile_nav_item mobile_orange page_nav w-inline-block w--current" href="/fellows">
#      <div>
#       FEllows
#      </div>
#     </a>
#     <a class="mobile_nav_item mobile_orange page_nav w-inline-block" href="http://insightdatascience.com/apply">
#      <div>
#       apply
#      </div>
#     </a>
#     <a class="mobile_nav_item mobile_orange page_nav w-inline-block" href="/faq">
#      <div>
#       FAQ
#      </div>
#     </a>
#     <a class="mobile_nav_item mobile_orange page_nav w-inline-block" href="https://blog.insightdatascience.com/tagged/insight-ai" target="_blank">
#      <div>
#       blog
#      </div>
#     </a>
#    </div>
#   </div>
#   <script crossorigin="anonymous" integrity="sha256-FgpCb/KJQlLNfOu91ta32o/NMZxltwRo8QtmkMRdAu8=" src="https://d1tdp7z6w94jbb.cloudfront.net/js/jquery-3.3.1.min.js" type="text/javascript">
#   </script>
#   <script src="https://uploads-ssl.webflow.com/57c954d37d70832a623199f5/js/insight-artificial-intelligence.c20b995fc.js" type="text/javascript">
#   </script>
#   <!--[if lte IE 9]><script src="//cdnjs.cloudflare.com/ajax/libs/placeholders/3.0.2/placeholders.min.js"></script><![endif]-->
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.0.3/jquery.min.js" type="text/javascript">
#   </script>
#   <script>
#    $(document).ready(function(){
# 	var fellow_width = $(".fellow_img").width();
#   $(".fellow_img").css("height",fellow_width);
#   $(".fellows_tooltip").css("bottom",fellow_width + 20);
#
# $(window).bind('resize', function(e) {
# window.resizeEvt;
# $(window).resize(function() {
# clearTimeout(window.resizeEvt);
# window.resizeEvt = setTimeout(function() {
#
# var fellow_width = $(".fellow_img").width();
# $(".fellow_img").css("height",fellow_width);
# $(".fellows_tooltip").css("bottom",fellow_width + 20);
#
# }, 10);
# });
# });
#
# 	$("#header_bt_3").addClass("active_item_orange");
#   $("#footer_bt_3").addClass("active_item_orange");
#   $("#header_bt_5").addClass("active_item_orange");
#   $("#footer_bt_5").addClass("active_item_orange");
#
#
#   // mobile side nav
# 	var nav = 0;
#
# 	$(".mobile_nav_button").click(function(){
# 		if ( nav == 1 ) {
# 			$("#full_website").animate({"right":"0%"}, 500);
# 			$("#side_nav_bar").animate({"right":"-80%"}, 500);
# 			nav = 0;
# 		} else {
# 			$("#full_website").animate({"right":"80%"}, 500);
# 			$("#side_nav_bar").animate({"right":"0%"}, 500);
# 			nav = 1;
# 		}
# 	});
#
#   // mobile section nav
#
#   var expanded = 0;
#
#   function expand_close() {
#   	if (expanded == 0) { $(".mobile_sub_nav").css("display","block"); expanded = 1; }
#     else { $(".mobile_sub_nav").css("display","none"); expanded = 0; }
#   }
#
#
#   $("#link_dropdown").click(function(){
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#   });
#
#   $("#mlink_program").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#   });
#
#   $("#mlink_fellows").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#    $("#mlink_mentorship").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#    $("#mlink_industry").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#    $("#mlink_community").click(function() {
#   	$('.mobile_active_nav').html($(this).html());
#     expand_close();
#    });
#
#
# 	window.f_slide = 1;
#   window.p_slide = 1;
#   window.m_slide = 1;
#   window.i_slide = 1;
#   window.c_slide = 1;
#   window.header_slide = 1;
#
# 		$("#link_program, #mlink_program").click(function(){
#   		$("#pslide_inner_container").animate({left:0}, 300);
# 		$("#pcircle_1").addClass("blue_filled");
# 		$("#pcircle_2, #pcircle_3, #pcircle_4, #pcircle_5, #pcircle_6, #pcircle_7, #pcircle_8, #pcircle_9").removeClass("blue_filled");
#
# 		p_slide = 1;
# 		$("#link_program").addClass("active_nav");
# 		$("#link_fellows, #link_mentorship, #link_industry, #link_community").removeClass("active_nav");
# 		$("#program_content").css("display","block");
# 		$("#fellows_content, #mentorship_content, #industry_content, #community_content").css("display","none");
# 	});
#
#   $("#link_fellows, #mlink_fellows").click(function(){
# 		$("#fslide_inner_container").animate({left:0}, 300);
# 		$("#fcircle_1").addClass("blue_filled");
# 		$("#fcircle_2, #fcircle_3, #fcircle_4, #fcircle_5, #fcircle_6, #fcircle_7, #fcircle_8, #fcircle_9").removeClass("blue_filled");
#
# 		f_slide = 1;
# 		$("#link_program, #link_mentorship, #link_industry, #link_community").removeClass("active_nav");
# 		$("#link_fellows").addClass("active_nav");
#
# 		$("#program_content, #mentorship_content, #industry_content, #community_content").css("display","none");
# 		$("#fellows_content").css("display","block");
# 	});
#
#
#
#
#   $("#gq_link").click(function(){
#   	$("#gq_link").addClass("active_faq_item");
#     $("#about_link").removeClass("active_faq_item");
#     $("#admissions_link").removeClass("active_faq_item");
#     $("#before_link").removeClass("active_faq_item");
#     $("#aboutr_link").removeClass("active_faq_item");
#   });
#
#   $("#about_link").click(function(){
#   	$("#gq_link").removeClass("active_faq_item");
#     $("#about_link").addClass("active_faq_item");
#     $("#admissions_link").removeClass("active_faq_item");
#     $("#before_link").removeClass("active_faq_item");
#     $("#aboutr_link").removeClass("active_faq_item");
#   });
#
#
#   $("#admissions_link").click(function(){
#   	$("#gq_link").removeClass("active_faq_item");
#     $("#about_link").removeClass("active_faq_item");
#     $("#admissions_link").addClass("active_faq_item");
#     $("#before_link").removeClass("active_faq_item");
#     $("#aboutr_link").removeClass("active_faq_item");
#   });
#
#
#   $("#before_link").click(function(){
#   	$("#gq_link").removeClass("active_faq_item");
#     $("#about_link").removeClass("active_faq_item");
#     $("#admissions_link").removeClass("active_faq_item");
#     $("#before_link").addClass("active_faq_item");
#     $("#aboutr_link").removeClass("active_faq_item");
#   });
#
#
#   $("#aboutr_link").click(function(){
#   	$("#gq_link").removeClass("active_faq_item");
#     $("#about_link").removeClass("active_faq_item");
#     $("#admissions_link").removeClass("active_faq_item");
#     $("#before_link").removeClass("active_faq_item");
#     $("#aboutr_link").addClass("active_faq_item");
#   });
#
# });
#   </script>
#  </body>
# </html>

# %% [markdown]
# All the information about each fellow is placed under a `<div>` section of class `fellows_tooltip`. let's see, for example, how this section looks like for the first fellow:

# %%
c = content.find('div', {'class':'fellows_tooltip'})
print(c.prettify())
# Out:
# <div class="fellows_tooltip">
#  <div class="arrow_down">
#  </div>
#  <div class="tooltip_header orange_header">
#   <div class="tooltip_header_container">
#    <div class="tooltip_name">
#     Anitha Priya Krishnan
#    </div>
#    <div class="toottip_title">
#     Bioinformatics scientist
#    </div>
#    <div class="comma">
#     ,
#    </div>
#    <div class="tooltip_company">
#     Chan Zuckerberg Biohub
#    </div>
#   </div>
#  </div>
#  <div class="tooltip_content">
#   <div class="tooltip_title">
#    Insight Project
#   </div>
#   <div class="tooltip_project">
#    Reducing the memory requirements of trained neural networks using weight pruning
#   </div>
#   <div class="tooltip_title">
#    background
#   </div>
#   <div class="tooltip_background">
#    Biomedical Engineering, Rochester University, PhD
#   </div>
#  </div>
# </div>

# %% [markdown]
# So all we have to do is to find all the `<div class="fellows_tooltip">` sections in the html and than for each instance append the name, title, company, project, and background of each fellow in to the corresponding list:

# %%
# create lists for every data element
fellow_name = []
fellow_title = []
fellow_company = []
fellow_project = []
fellow_background = []

# find all the fellow tool tips and append each data element to the corresponding list
for tooltip in content.find_all('div', {'class':'fellows_tooltip'}):
    fellow_name.append(tooltip.find('div', {'class':'tooltip_name'}).text)
    fellow_title.append(tooltip.find('div', {'class':'toottip_title'}).text)
    fellow_company.append(tooltip.find('div', {'class':'tooltip_company'}).text)
    fellow_project.append(tooltip.find('div', {'class':'tooltip_project'}).text)
    fellow_background.append(tooltip.find('div', {'class':'tooltip_background'}).text)

# create a dictionary to hold all the data
data = {'name':fellow_name, 'title':fellow_title, 'company':fellow_company,\
        'project':fellow_project, 'background':fellow_background}

# %%
fellow_data = pd.DataFrame(data) # data frame of fellows data
num_fellows = len(fellow_data.index) # total number of fellows 
fellow_data
# Out:
#                      name                                    title  \
# 0   Anitha Priya Krishnan                 Bioinformatics scientist
# 1                 Bob Guo                      Senior ML Scientist
# 2            David Gainer                        Software Engineer
# 3        Drumil Deshpande                   Software Engineer - ML
# 4        Emmanuel Ameisen                                  AI Lead
# 5              Edward Kim                              ML Engineer
# 6        Jeffrey Hetherly          Deep Learning Software Engineer
# 7                 Lily Hu                       Research Scientist
# 8            Markus Huber                    Senior Data Scientist
# 9         Natalie Serrino                        Founding Engineer
# 10         Ramesh Sampath                   Deep Learning Engineer
# 11         Richard Fisher             NLP / Deep Learning Engineer
# 12               Yao Zhao                     Applied Scientist II
# 13           Zhonglin Han      Senior Engineer of Machine Learning
# 14          Zhongyu Kuang                        Software Engineer
# 15      Andrew Mauboussin                           Data Scientist
# 16          Bruno Guisard                Machine Learning Engineer
# 17          Chuck-Hou Yee       Machine Learning Research Engineer
# 18       Florent Bekerman  Software Engineering - Machine Learning
# 19        Gianni Galbiati                        Research Engineer
# 20   Godfred Somua-Gyimah                           Data Scientist
# 21       Jashmi Lagisetty                           Data Scientist
# 22            John Riskas         Applied Deep Learning Researcher
# 23           Jonathan Kyl             Artificial Intelligence Lead
# 24    Prashanth Harshangi                      Senior AI Scientist
# 25           Yuri Plotkin        Senior Machine Learning Scientist
# 26         Alexander Wahl                        Software Engineer
# 27      Chia-Chun (JJ) Fu                Senior Research Scientist
# 28            Daniel Chun
# 29              Jack Kwok      Software Engineer, Machine Learning
# 30       Javed Qadrud-Din                              ML Engineer
# 31             Jiaming Hu                  Deep Learning Scientist
# 32      Kun-Hua (Eric) Tu      Machine Learning Research Scientist
# 33              Max Quinn           AI Research & Engineering Lead
# 34       Narek Dshkhunyan                  Computational Biologist
# 35        Sai MarapaReddy                            ML Consultant
# 36    Sravya Tirukkovalur                       Senior ML Engineer
# 37      Stefano Cosentino                           Data Scientist
# 38          Yen-Chun Chen                             ML Scientist
# 39          Andrew Morten                        Software Engineer
# 40           Ashwin Kumar                  Deep Learning Scientist
# 41             Ben Hammel                  Deep Learning Scientist
# 42             Bowen Yang                             ML Scientist
# 43           Bryant Chhun                             R&D Engineer
# 44              Chao Deng                           Data Scientist
# 45           Felipe Mejia                           Data Scientist
# 46             Ryan Reece                              ML Engineer
# 47            Shoaib Khan                           Data Scientist
# 48         Sumeet Agrawal                              ML Engineer
# 49         Tianxiao Jiang                   Technical Staff Member
# 50       Victor Suthichai              SDE, Deep Learning Platform
#
#                      company  \
# 0     Chan Zuckerberg Biohub
# 1               Amazon Alexa
# 2                     Google
# 3                 Applicantz
# 4                    Insight
# 5                      Agero
# 6                     NVIDIA
# 7        Salesforce Research
# 8        Climate Corporation
# 9            Stealth Startup
# 10                   Lily AI
# 11               Mya Systems
# 12   Microsoft AI & Research
# 13                     Smule
# 14                    Google
# 15                   Twitter
# 16       Liftoff Mobile, Inc
# 17       Imagen Technologies
# 18                  LinkedIn
# 19                   Vidrovr
# 20          Monsanto Company
# 21            SparkCognition
# 22              DigitalGlobe
# 23                 JobMap.ai
# 24                       NIO
# 25         Cofactor Genomics
# 26                   Invitae
# 27     Blue River Technology
# 28                       Mya
# 29                      Lyft
# 30                  Casetext
# 31              Mythic, Inc.
# 32               Buoy Health
# 33                  Bluewolf
# 34              10X Genomics
# 35                    Huawei
# 36                     Adobe
# 37  Bosch Autonomous Driving
# 38                 Stackline
# 39              Mythic, Inc.
# 40              Mythic, Inc.
# 41              Mythic, Inc.
# 42                 SambaNova
# 43    Chan Zuckerberg Biohub
# 44                    C3 IoT
# 45            In-Q-Tel Lab41
# 46          Cerebras Systems
# 47       Manifold Technology
# 48   Microsoft AI & Research
# 49          Cerebras Systems
# 50                Amazon AWS
#
#                                               project  \
# 0   Reducing the memory requirements of trained ne...
# 1   Colorizing gray images using HyperColumns and ...
# 2   Bringing Synthetic Faces to Life using deep le...
# 3   An end to end system to generate tags and capt...
# 4            Applying Neural Style Transfer to Speech
# 5                    Real-time video super-resolution
# 6                Audio upsampling using deep learning
# 7   CNNs for image segmentation to separate overla...
# 8   Generation of artificial images of face aging ...
# 9   Generating complementary harmonies for melody ...
# 10  Fashion apparel attributes API using deep lear...
# 11  Implementing Fast Weights, a new memory archit...
# 12  Generating realistic images from captions, usi...
# 13  Audio Classification for Cobalt Robotics using...
# 14  Automatically adding/removing smiles from face...
# 15  Explaining the predictions of any (text) class...
# 16     Davis: Deep Learning Analytics in Video Stream
# 17  Cardiac MRI segmentation: Using deep nets to i...
# 18                  Detecting links on network graphs
# 19    Unsupervised learning for video representations
# 20  SmartSurv: A 3D CNN that recognizes actions in...
# 21  Image encoding and reconstruction using convol...
# 22            CureSkin: A deep learning dermatologist
# 23  Show & Tell at first sight: 1-shot image capti...
# 24  What do you see? Using deep learning for image...
# 25  Title generation using text summarization: A d...
# 26                           Triaging Medical Queries
# 27                                            TinyNet
# 28                 Code Judge: Deep Learning Edition
# 29                              Neural Road Inspector
# 30                                         entity2vec
# 31               Automatic Training for Deep Learning
# 32                                            SnapCat
# 33                           Chatbot with Personality
# 34                            Making Smarter Chatbots
# 35                                        Sentence AI
# 36                                          VideoText
# 37                           Speech to the Speechless
# 38                       Bridging Vision and Language
# 39  openLIS: Searching data faster with machine le...
# 40      SketchCode: Never write front-end code again!
# 41  Faraway Farms: Counting Sheep without Falling ...
# 42     Hero2vec: Forsee the game with hero embeddings
# 43      Sounding Off: Heart diagnostics from anywhere
# 44               Who Speaks: Let Every Voice Be Heard
# 45  The Force Awakens: Computer Vision for Home Co...
# 46                        HYPR.AI: Cloud-based AutoML
# 47   Speak Again: Giving Voice to the Speech Impaired
# 48  Thumbnails for Videos: A thumbnail worth a tho...
# 49             SimpleText: Neural Text Simplification
# 50  Pair-a-phrase it: Siri: Sorry, I didn’t get that.
#
#                                            background
# 0   Biomedical Engineering, Rochester University, PhD
# 1      Electrical Engineering, Peking University, PhD
# 2           Computer Science, Columbia University, MS
# 3         Computer Science, University of Florida, MS
# 4                              Data Scientist, Zipcar
# 5   Astronomy, University of Illinois Urbana-Champ...
# 6         Physics, Southern Methodist University, PhD
# 7            Mechanical Engineering, UC Berkeley, PhD
# 8   Astrophysics, Ludwig-Maximillians University, PhD
# 9                  Senior Software Engineer, Trifacta
# 10               Engineering Fellow, Code for America
# 11                           Software Engineer, Myolo
# 12              Applied Physics, Yale University, PhD
# 13               Nuclear Physics, Duke University, MS
# 14       Atmospheric Science, Rutgers University, PhD
# 15  Data Scientist and Engineer, Kensho Technologi...
# 16  Director of International Delta One and Arbitr...
# 17                   Physics, Rutgers University, PhD
# 18                              Mathematics, MIT, PhD
# 19  Computational Psychology and Neuroscience, NYU...
# 20  Mining Engineering, Missouri University of Sci...
# 21     Computer Science, Arizona State University, MS
# 22  Emerging Markets Synthetic Equities Delta One ...
# 23        Computer Science, University of Chicago, MS
# 24             Adaptive Systems, Yale University, PhD
# 25    Biomedical Engineering, Columbia University, MS
# 26                 Linguistics, UC Santa Barbara, PhD
# 27        Chemical Engineering, UC Santa Barbara, PhD
# 28              Algebraic Geometry, UC Riverside, PhD
# 29                  Staff Software Engineer, LinkedIn
# 30                     Business Architect, IBM Watson
# 31     Computer Science, University of Washington, MS
# 32                        Materials Science, MIT, PhD
# 33                         Senior Manager, Salesforce
# 34    Computer Science and Molecular Biology, MIT, MS
# 35  Software Engineer, Brocade Communications Systems
# 36                                  VP, Apache Sentry
# 37  Modelling & Speech Enhancement, University Col...
# 38  Computer Science, University of North Carolina...
# 39               Physics, University of Michigan, PhD
# 40          CEO and Co-Founder, Sway Finance (YC S16)
# 41            Physics, University of Nevada Reno, PhD
# 42  Physics and Astronomy, University of Californi...
# 43                    Imaging Scientist, Singular Bio
# 44  Computational Biology and Bioinformatics, Univ...
# 45          Mechanical Engineering, UC San Diego, PhD
# 46           Physics, University of Pennsylvania, PhD
# 47  Computer Science and Engineering & Applied Phy...
# 48  Data Science, University of Southern Californi...
# 49  Computational Neuroscience, University of Hous...
# 50                       Senior ML Engineer, eHarmony

# %% [markdown]
# ### Analyze data

# %% [markdown]
# Let's explore the background education of the fellows

# %%
PhD_percentage = 100 * sum(fellow_data['background'].str.contains('PhD'))/num_fellows
MS_percentage = 100 * sum(fellow_data['background'].str.contains('MS'))/num_fellows
other_percentage = 100 - PhD_percentage - MS_percentage

education = ['PhD', 'MS', 'Other']
ed_percentage = [PhD_percentage, MS_percentage, other_percentage]
fellows_education = pd.Series(data= ed_percentage, index= education)


plt.figure()
plt.rcParams.update({'font.size': 16})
fellows_education.plot('bar')
plt.xlabel('Fellow\'s education')
plt.ylabel('Percentage')
for i,v in enumerate(fellows_education):
    plt.text(i -.2, v/2, str(round(v,1)), fontweight = 'bold')

# %% [markdown]
# #### What fields of in the academia are they coming from?

# %%
Physics = 100 * sum(fellow_data['background'].str.contains('Physics').tolist() or \
                    fellow_data['background'].str.contains('Astrophysics').tolist() or \
                    fellow_data['background'].str.contains('Astronomy').tolist())/num_fellows
Math = 100 * sum(fellow_data['background'].str.contains('Mathematics'))/num_fellows
CS = 100 * sum(fellow_data['background'].str.contains('Computer').tolist() or \
               fellow_data['background'].str.contains('Computational').tolist())/num_fellows
Materials = 100 * sum(fellow_data['background'].str.contains('Materials'))/num_fellows
other = 100 - (Physics + Math + CS + Materials)

edu_field = ['Physics', 'Math', 'CS', 'Materials', 'other']
field_percentage = [Physics, Math, CS, Materials, other]
fellows_field = pd.Series(field_percentage, index = edu_field)

plt.figure()
plt.rcParams.update({'font.size': 16})
fellows_field.plot('bar')
plt.xlabel('Fellow\'s field')
plt.ylabel('Percentage')
for i,v in enumerate(fellows_field):
    plt.text(i -.25, v/2, str(round(v,1)), fontweight = 'bold')

# %% [markdown]
# #### What are the most common companies for fellows to work for after the program?

# %%
companies = fellow_data.company.value_counts()
companies_per = 100*companies[companies>1]/num_fellows # show percentage for companies with more than one employee
companies_per.plot('bar')
 
plt.ylabel('percentage of fellows')
for i,v in enumerate(companies_per):
    plt.text(i -.2, v/2, str(round(v,1)), fontweight = 'bold')

# %% [markdown]
# #### What are the most common titles of fellows after the program?

# %%
titles = fellow_data.title.value_counts()
titles_per = 100*titles[titles>1]/num_fellows
titles_per.plot('bar')
plt.ylabel('percentage of fellows')
for i,v in enumerate(titles_per):
    plt.text(i -.2, v/2, str(round(v,1)), fontweight = 'bold')

# %% [markdown]
# Very interesting, most of the AI fellows end up getting data scientist positions. I wonder how many fellows that end up with a scientist positions have PhD:

# %%
DSPhD = 100*fellow_data[fellow_data.title.str.contains('Scientist')].background.str.contains('PhD').mean()
DSMS = 100*fellow_data[fellow_data.title.str.contains('Scientist')].background.str.contains('MS').mean()
DS = 100*fellow_data[fellow_data.title.str.contains('Scientist')].background.str.contains('Data Scientist').mean()
other = 100-DSPhD -DSMS -DS

scientists = pd.Series([DSPhD, DSMS, DS, other], index = ['PhD','MS', 'Data Science','other'])

scientists.plot('bar')
plt.xlabel('fellow\'s background')
plt.ylabel('percentage')
for i,v in enumerate(scientists):
    plt.text(i -.25, v/2, str(round(v,1)), fontweight = 'bold')

# %% [markdown]
# We see that 90% of people from the AI program that end up getting a scientist positions had a PhD or MS the out of the rest, 5% where already had a previous background as data scientists. Let's check the last 5%:
