# %% [markdown]
# # Scraping insight Data Science fellows data

# %% [markdown]
# In this notebook, I'll extract data about insight fellows in order to learn more about past programs fellows and the kind of jobs they obtain after completing the program. I'll use `requests` for obtaining webpages, `Beautiful Soup` for parsing webpages and extracting data and `pandas` for analyzing the data.

# %% [markdown]
# ### import libraries:

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get web page:

# %%
url = 'https://www.insightdatascience.com/fellows'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# This is the [HTTP response status code](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status) that was received. For example: 200 - means succsess and 404 - means not found.

# %% [markdown]
# ### Extract content:

# %% [markdown]
# First, let's look at the entire html structure to understand how it is built and what would we want to extract

# %%
content = BeautifulSoup(response.content, 'html.parser')
# print(content.prettify())

# %% [markdown]
# In this case there are a lot of fellows and therefore our data is distributed across a few pages. Let's start by extracting the links to all the pages we need:

# %%
urls = []
urls.append(url)
a = content.find('a', {'class':'w-pagination-next'})

while a:
    next_url = url + a['href']
    urls.append(next_url)
    r = requests.get(next_url)
    c = BeautifulSoup(r.content, 'html.parser')
    a = c.find('a', {'class':'w-pagination-next'})
    
urls
# Out:
# ['https://www.insightdatascience.com/fellows',
#  'https://www.insightdatascience.com/fellows?61ea5d1b_page=2',
#  'https://www.insightdatascience.com/fellows?61ea5d1b_page=3',
#  'https://www.insightdatascience.com/fellows?61ea5d1b_page=4',
#  'https://www.insightdatascience.com/fellows?61ea5d1b_page=5',
#  'https://www.insightdatascience.com/fellows?61ea5d1b_page=6',
#  'https://www.insightdatascience.com/fellows?61ea5d1b_page=7',
#  'https://www.insightdatascience.com/fellows?61ea5d1b_page=8']

# %% [markdown]
# All the information about each fellow is placed under a `<div>` section of class `fellows_tooltip`, So all we have to do is to find all the `<div class="fellows_tooltip">` sections in each one of the urls and then for each instance append the name, title, company, project, and background of each fellow in to the corresponding list:

# %%
# create lists for every data element
fellow_name = []
fellow_title = []
fellow_company = []
fellow_project = []
fellow_background = []

for u in urls:
    r = requests.get(u)
    c = BeautifulSoup(r.content, 'html.parser')
    # find all the fellow tool tips and append each data element to the corresponding list
    for tooltip in c.find_all('div', {'class':'fellows_tooltip'}):
        fellow_name.append(tooltip.find('div', {'class':'tooltip_name'}).text)
        fellow_title.append(tooltip.find('div', {'class':'toottip_title'}).text)
        fellow_company.append(tooltip.find('div', {'class':'tooltip_company'}).text)
        fellow_project.append(tooltip.find('div', {'class':'tooltip_project'}).text)
        fellow_background.append(tooltip.find('div', {'class':'tooltip_background'}).text)

# create a dictionary to hold all the data
data = {'name':fellow_name, 'title':fellow_title, 'company':fellow_company,\
        'project':fellow_project, 'background':fellow_background}

# %%
fellow_data = pd.DataFrame(data) # data frame of fellows data
num_fellows = len(fellow_data.index) # total number of fellows 
fellow_data
# Out:
#                           name                                    title  \
# 0                      JP Bida                         Director of Risk
# 1                Douglas Mason                           Data Scientist
# 2    Virot Ta Chiraphadhanakul                           Data Scientist
# 3              Julia Viladomat                           Data Scientist
# 4                David Freeman           Head of Anti-Abuse Engineering
# 5               Jessica Zúñiga                    Senior Data Scientist
# 6                Harold Nguyen                           Data Scientist
# 7       Sebastien de Larquier                            Data Scientist
# 8           Paula Therese Lang                    Senior Data Scientist
# 9                       Nan Ma                            Data Engineer
# 10              Cinna Julie Wu                           Data Scientist
# 11                Erin Summers                        Software Engineer
# 12                Leah McGuire                    Senior Data Scientist
# 13                  Nick Bunch                     Quantitative Analyst
# 14              Shelby Sturgis       Senior Data Visualization Engineer
# 15                 Onkar Dalal                           Data Scientist
# 16                 Aastha Jain                           Data Scientist
# 17                    Yan Yang                            Data Engineer
# 18            Puneeth Kalavase                      Algorithm Developer
# 19            Efraim Feinstein                           Data Scientist
# 20               Joe Gallagher                                Data Lead
# 21              Justin Parella                           Data Scientist
# 22                  Andre Bach                           Data Scientist
# 23                   Keoki Seu                            Data Engineer
# 24           Prakhar Mehirotra      Quantitative Analytics Finance Lead
# 25              Vincent Fusaro  Senior Software Engineer Technical Lead
# 26                    Diane Wu                                  Founder
# 27          Giovanna Miritello                           Data Scientist
# 28     Dominique Van de Sompel                           Data Scientist
# 29               Colin Dillard                          Data Scientist
# ..                         ...                                      ...
# 764              David Cameron                           Data Scientist
# 765            Amruta Varudkar                           Data Scientist
# 766                 Yvonne Lin                           Data Scientist
# 767                Adam Jacoby                           Data Scientist
# 768             Alexey Shmelev                           Data Scientist
# 769                Bahar Zarin                           Data Scientist
# 770  Chalence Safranek-Shrader                           Data Scientist
# 771               Charlie Hogg                           Data Scientist
# 772             David Christle                           Data Scientist
# 773                Jason Kamin                           Data Scientist
# 774                  Jeff Camp                           Data Scientist
# 775                  Jon Witte                           Data Scientist
# 776               Ketki Sharma                           Data Scientist
# 777             Kirsten Smayda                           Data Scientist
# 778               Matthew Sims
# 779               Meghan Frate                           Data Scientist
# 780               Michael Saha                           Data Scientist
# 781                   Yuwen Wu                           Data Scientist
# 782                 Liz Baldo                            Data Scientist
# 783        Stephanie Sorenson                           Data Scientist
# 784              Steven Felix                         Research Analyst
# 785           Tatyana Perlova                           Data Scientist
# 786             Bridget Salna                           Data Scientist
# 787          Esteban Urdiales                           Data Scientist
# 788                Jason Rute                           Data Scientist
# 789              Samta Shukla                           Data Scientist
# 790               Yossi Cohen                         Research Analyst
# 791         Pawan Nandakishore                          Data Scientist
# 792           Margaret Kosmala                          Data Scientist
# 793                    Wei He                           Data Scientist
#
#                 company                                            project  \
# 0           Capital One  Measuring the Impact of Open Source Coders on ...
# 1               Twitter    Email Searcher: Search & Visualize Your Mailbox
# 2              Facebook  Tweet Timeline: Visualizing the Impact of Soci...
# 3                 Adobe           Sentiment Analysis Based on Social Media
# 4              LinkedIn                             Flight Delay Predictor
# 5              LinkedIn      Email Contacts Automatically Grouped & Ranked
# 6            Proofpoint           Analysis of New York Stop-and-Frisk Data
# 7               Netflix           CouchTube: YouTube TV shows in one click
# 8          CreativeLIVE  SchoolGeo: Empowering Parents to Make Informed...
# 9      Microsoft Yammer             Event Map: Get Local News from Twitter
# 10             Facebook  Sort My Friends: Automatically Organize your C...
# 11             Facebook           Flat Finder: Find Your Perfect Apartment
# 12             LinkedIn                                  Kiva Loan Checker
# 13              YouTube     Arrive in Time: Airport Arrival Time Predictor
# 14              Netflix  STARtrack: Helping Educators Track Student Per...
# 15             LinkedIn                     Diverse Recipe Recommendations
# 16             LinkedIn                       Multi-Domain Recommendations
# 17     Microsoft Yammer                        Stock Volatility Predictor
# 18             PlotWatt                        Lower Your Electricity Bill
# 19   Level Up Analytics                  Find the Expert on Stack Overflow
# 20               Reddit          RewindX: Rediscover Music From Your Youth
# 21             Facebook  HipHopper: Find The Musicians You Have Been Mi...
# 22                 Uber            RouteAroundCrime: The Path Less Mugged
# 23             Facebook  FlockThink: Twitter Search Engine For Instant ...
# 24                 Uber  News Now: Scrapes the RSS feeds from popular n...
# 25              InVitae  RxDiscovery: Mining the FDA's adverse event da...
# 26      Trace Genomics           BakeSearch: Stop Searching & Start Baking
# 27          Telefonica                ReadTweetApp: The Tweets That Matter
# 28             Facebook    TwinkedIn: Follow LinkedIn Contacts on Twitter
# 29   Level Up Analytics     CrimeVis: Visualization of Oakland Crime Rates
# ..                  ...                                                ...
# 764             Netflix  Awesome Hockey: What to skip and what to watch...
# 765              Acxiom  Evolutionary Biology & Population Genetics, St...
# 766      Social Capital  BeautyExtract: A data product to empower custo...
# 767            LinkedIn  Rapid Chat Made Slow: Extracting content from ...
# 768               Bosch         TireCheck: Check your tire wear in seconds
# 769            Facebook      SignatureFood: Make sure you enjoy your meal!
# 770           FiveStars  TexanTurnout: Predicting the Voter Turnout Rat...
# 771       Rasa Networks  Pic My Plant: Growing a garden rooted in deep ...
# 772            LinkedIn  HitCoin!: Data mining Internet hype to find th...
# 773        Mercedes R&D                   Cairnfinder: An Alpinist's Guide
# 774            Facebook  DiversifyMe: Interactive visualization of corr...
# 775              Indeed                     LiFT: The Lifting Form Trainer
# 776              Remind                       Q-tagger: Tag your questions
# 777   Pear Therapeutics                          Gobble: Cookin' with data
# 778  Basis Set Ventures  ImageGen: Automating Image Recommendations for...
# 779            LinkedIn   InstaStudio: Instantly Find a Studio You'll Love
# 780            Facebook              LegalTech: Startup Consulting Project
# 781              Intuit  EmailViz: Identifying employee relationships f...
# 782             Indigo   Find Your Art: Discover artwork around you usi...
# 783            Wayfair   Churn-No-More: Discovering what drives custome...
# 784         Wellington   Search Suggestor: Improving Stack Overflow sea...
# 785             Indigo       MicrobeX: Exploring microbes across the globe
# 786              Cinch   AdviceDice: Board game recommendations that le...
# 787              IvySys  AirbnMe: Predicting Airbnb Occupancy Rates for...
# 788                CiBO  CallMeBackMaybe: Using natural language proces...
# 789         CVS Health   SaReGaMood: Mood-based playlists for Indian cl...
# 790         Wellington   Flightstitute: Risk management for flight disr...
# 791          Colaberry   Joke's on you!: Identifying humor and inapprop...
# 792                CiBO  Mountain Bike Forecast: Predicting riding cond...
# 793         CVS Health   Customer prioritization: Predicting a consumer...
#
#                                             background
# 0                       Bio-X Games, Stanford, Postdoc
# 1                   Physics, Harvard University, PhD\n
# 2                        Operations Research, MIT, PhD
# 3                        Statistics, Stanford, Postdoc
# 4                       Mathematics, Stanford, Postdoc
# 5                           Mathematics, Duke, Postdoc
# 6                           Physics, UC Riverside, PhD
# 7                     Space Physics, Virgina Tech, PhD
# 8          Computational Biology, UC Berkeley, Postdoc
# 9    Electrical Engineering & Computer Science, UC ...
# 10               Applied Mathematics, UC Berkeley, PhD
# 11   Electrical Engineering & Computer Science, UC ...
# 12    Computational Neuroscience, UC Berkeley, Postdoc
# 13             Space Plasma Physics, Stanford, Postdoc
# 14                              Biology, Stanford, PhD
# 15   Computational & Mathematical Engineering, Stan...
# 16   Computer Vision & Image Processing, Johns Hopk...
# 17   Computational & Mathematical Engineering, Stan...
# 18          Environmental Energy, UC Berkeley, Postdoc
# 19   Computational Biophysics, Harvard University, ...
# 20       Computational Neuroscience, Stanford, Postdoc
# 21                 Atmospheric Chemistry, Harvard, PhD
# 22     Experimental Particle Physics, UC Berkeley, PhD
# 23   Condensed Matter Physics, Lawrence Berkeley Na...
# 24   Aeronautics, California Institute of Technolog...
# 25   Clinical Translational Informatics, Harvard Me...
# 26                             Genetics, Stanford, PhD
# 27   Mathematical Engineering, University Carlos II...
# 28                Molecular Imaging, Stanford, Postdoc
# 29                    Physics, Harvard University, PhD
# ..                                                 ...
# 764    Energy Resources Engineering, Stanford, Postdoc
# 765                        ArtPricer: Sell it already!
# 766         Statistics, University of Waterloo, B.Math
# 767                Mathematics, Temple University, PhD
# 768                   Mechanical Engineering, MIT, PhD
# 769  Civil Engineering (Transportation), University...
# 770  Astrophysics, University of California, Berkel...
# 771  Mathematics/Environmental Engineering, Stanfor...
# 772  Quantum Science & Engineering, University of C...
# 773            Nuclear Particle Physics, CERN, Postdoc
# 774  Chemical Engineering, Lawrence Berkeley Nation...
# 775  Theoretical Chemistry, University of Californi...
# 776  Environmental Engineering, Georgia Institute o...
# 777  Cognitive Neuroscience, The University of Texa...
# 778                English, University of Chicago, PhD
# 779      Experimental Particle Physics, UC Irvine, PhD
# 780  Environmental Sciences, The University of Virg...
# 781              Neuroscience, Harvard University, PhD
# 782  Hydrology and Water Resources Engineering, UCL...
# 783               Psychology, Stanford University, PhD
# 784  Experimental Psychopathology, Harvard Universi...
# 785  Physics, University of Illinois at Urbana-Cham...
# 786              Physics, Northeastern University, PhD
# 787  Applied Mathematics, Northwestern University, PhD
# 788        Mathematical Sciences, Carnegie Mellon, PhD
# 789      Computer Systems, Rensselaer Polytechnic, PhD
# 790       Theoretical Physics, Weizmann Institute, PhD
# 791  Fracture Mechanics, Max Planck Institute for D...
# 792              Ecology, University of Minnesota, PhD
# 793  Physics, University of Massachusetts Amherst, PhD
#
# [794 rows x 5 columns]

# %% [markdown]
# How many fellows do we have in this dataset?

# %%
num_fellows
# Out:
# 794

# %% [markdown]
# ### Analyze data

# %% [markdown]
# Let's explore the background education of the fellows

# %%
PhD_percentage = 100 * sum(fellow_data['background'].str.contains('PhD'))/num_fellows
Post_percentage = 100 * sum(fellow_data['background'].str.contains('Postdoc'))/num_fellows
MS_percentage = 100 * sum(fellow_data['background'].str.contains('MS'))/num_fellows
other_percentage = 100 - PhD_percentage - MS_percentage - Post_percentage

education = ['PhD', 'Postdoc', 'MS', 'Other']
ed_percentage = [PhD_percentage, Post_percentage, MS_percentage, other_percentage]
fellows_education = pd.Series(data= ed_percentage, index= education)


plt.figure()
plt.rcParams.update({'font.size': 16})
fellows_education.plot('bar')
plt.xlabel('Fellow\'s education')
plt.ylabel('Percentage')
for i,v in enumerate(fellows_education):
    plt.text(i -.2, v/2, str(round(v,1)), fontweight = 'bold')

# %% [markdown]
# We have 7.7% which are not PhD, Postdocs or MS. Let's check their background:

# %%
pd.set_option('display.max_colwidth', -1)
fellow_data[~(fellow_data['background'].str.contains('PhD') | fellow_data['background'].str.contains('Postdoc'))].background
# Out:
# 42     Probability Theory and Stochastic Processes,
# 106    Civil Engineering, Geophysics, Caltech/California Institute of Technology
# 132    Systems Neuroscience, Weill Cornell Medical College, Faculty
# 133    Astrophysics, Niels Bohr Institute, Copenhagen University, Faculty
# 182    Physics, Stanford, Systems Engineer
# 186    Astrophysics, Penn State, Adjunct Faculty
# 201    Physics, Lawrence Berkeley National Lab Scientist
# 263    High Energy Particle Physics, California Polytechnic State University, Lecturer
# 265    High Performance Computing, University of Chicago, Staff
# 273    Astrophysics, California Institute of Technology, Staff
# 278    Analytics & Strategy, Agricultural Microfinance, One Acre Fund, Manager
# 285    Computing, MIT, Fellow
# 301    Physics, University of Utah, Research Professor
# 303    Astrophysics, Yale, Associate Research Scientist
# 329    Brain & Cognitive Sciences, MIT, Research Scientist
# 330    Fluid Mechanics, Stanford, Research Associate
# 336    Psychology/Behavioral Medicine, UCSF, Assistant Professor, Clinical Health
# 341    Water Science, Drexel University, Faculty
# 346    Evident Point Software, Software Developer
# 351    Astrophysics, Pennsylvania State University, Research Faculty
# 358    Bioengineering, NYU School of Medicine, Associate Research Scientist
# 371    Electrical & Computer Engineering, University of Colorado, Boulder, Faculty
# 375    Data Science, Duimstra Consulting, Principal
# 378    Statistics & Mathematics, Johns Hopkins University, Faculty
# 429    Human Biology, Child Mind Institute / Nathan Kline Institute, Research Project Manager
# 430    Mathematics, United States Military Academy - West Point, Assistant Professor
# 437    Neuroscience, New York University, Associate Research Scientist
# 441    Civil Engineering, NYU Center for Urban Science & Progress, Research Associate
# 489    Physics, Claremont Colleges, Faculty
# 498    Computer Science, Wayne State University, Research Assistant
#                                    ...
# 507    Atmospheric and Oceanic Sciences, Columbia University, Lecturer
# 512    FMC Technologies, Research Scientist - Data Analytics
# 513    CERN, Assistant Scientist - High-Energy Physics
# 542    Astrophysics, University of Arizona, Assistant Research Scientist
# 549    Neuroscience, University of Geneva, Research Consultant
# 550    BP America, Geophysicist
# 554    US Citizenship and Immigration Services, Branch Chief - Data Science and Screening Analytics
# 559    Department of Innovation and Technology, City of Boston, Data Scientist
# 561    Ropes & Gray LLP, Technical Advisor
# 562    Rudin Management, Head Data Scientist
# 563    Binary Services, Quantitative Analyst
# 591    Economics, University of Auckland, Assistant Professor
# 592    Materials Science, University of Oxford, DPhil
# 618    Astrophysics, Stony Brook University, Research Faculty
# 620    Electrical Engineering, Polyera, Principal Scientist
# 662    Chemical Engineering,
# 692    Electrical Engineering, Stanford University, ABD
# 694    Department of Energy, Science and Technology Policy Fellow
# 709    Biomedical Engineering, University of Missouri at Columbia, Sr. Research Scientist
# 714    Ecology, Duke University, Research Scientist
# 718    Biological Psychology, National Institute of Mental Health, Senior Scientific Program Manager
# 719    Biomedical Engineering, Salk Institute for Biological Studies, Image Analysis Engineer
# 721    Astronomy, Sapling Learning, Project Manager
# 723    Chemistry, Intel Custom Foundry, Product Development Engineer
# 724    Quantum Computing, UC Berkeley, Visiting Scholar
# 729    Bioengineering (Synthetic and Systems Biology), University of Washington, Faculty Acting Assistant Professor
# 749    Astronomy, NASA Frontier Development Lab, Ph.D.
# 761    Economics, Stanford University, Research Associate
# 765    ArtPricer: Sell it already!
# 766    Statistics, University of Waterloo, B.Math
# Name: background, Length: 61, dtype: object

# %% [markdown]
# #### What fields of in the academia are they coming from?

# %%
Physics = 100 * sum(fellow_data['background'].str.contains('Physics')\
                    | fellow_data['background'].str.contains('Astrophysics')\
                    | fellow_data['background'].str.contains('Astronomy'))/num_fellows
Math = 100 * sum(fellow_data['background'].str.contains('Mathematics'))/num_fellows
CS = 100 * sum(fellow_data['background'].str.contains('Computer') \
               | fellow_data['background'].str.contains('Computational'))/num_fellows
Materials = 100 * sum(fellow_data['background'].str.contains('Materials'))/num_fellows
other = 100 - (Physics + Math + CS + Materials)

edu_field = ['Physics', 'Math', 'CS', 'Materials', 'other']
field_percentage = [Physics, Math, CS, Materials, other]
fellows_field = pd.Series(field_percentage, index = edu_field)

plt.figure()
plt.rcParams.update({'font.size': 16})
fellows_field.plot('bar')
plt.xlabel('Fellow\'s field')
plt.ylabel('Percentage')
for i,v in enumerate(fellows_field):
    plt.text(i -.25, v/2, str(round(v,1)), fontweight = 'bold')

# %% [markdown]
# #### What are the most common companies for fellows to work for after the program?

# %%
companies = fellow_data.company.value_counts()
companies_per = 100*companies.head(10)/num_fellows # show percentage for top 10 companies
companies_per.plot('bar')
 
plt.ylabel('percentage of fellows')
for i,v in enumerate(companies_per):
    plt.text(i -.25, v/2, str(round(v,1)), fontweight = 'bold')

# %% [markdown]
# #### What are the most common titles of fellows after the program?

# %%
titles = fellow_data.title.value_counts()
titles_per = 100*titles.head(10)/num_fellows
titles_per.plot('bar')
plt.ylabel('percentage of fellows')
for i,v in enumerate(titles_per):
    plt.text(i -.2, v/2, str(round(v,1)), fontweight = 'bold')

# %% [markdown]
# Very interesting, most of the AI fellows end up getting data scientist positions. I wonder how many fellows that end up with a scientist positions have PhD:

# %%
scientist_title = fellow_data[fellow_data.title.str.contains('Scientist')]
DSPhD = 100*scientist_title.background.str.contains('PhD').mean()
DSMS = 100*scientist_title.background.str.contains('MS').mean()
DS = 100*scientist_title.background.str.contains('Data Scientist').mean()
other = 100-DSPhD -DSMS -DS

scientists = pd.Series([DSPhD, DSMS, DS, other], index = ['PhD','MS', 'Data Science','other'])

scientists.plot('bar')
plt.xlabel('fellow\'s background')
plt.ylabel('percentage')
for i,v in enumerate(scientists):
    plt.text(i -.25, v/2, str(round(v,1)), fontweight = 'bold')

# %% [markdown]
# We see that 90% of people from the AI program that end up getting a scientist positions had a PhD or MS the out of the rest, 5% where already had a previous background as data scientists. Let's check the last 5%:

# %%
scientist_title[~scientist_title.background.str.contains('PhD')
                & ~scientist_title.background.str.contains('MS')
                & ~scientist_title.background.str.contains('Data Scientist')]
